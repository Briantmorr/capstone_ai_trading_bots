# %%
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
from alpaca.data.historical import StockHistoricalDataClient

# %%
api_key="PK2DSD4BN8QNOYWSC5I1"
secret_key="eGSHvlwHLcuf24k0cTKXDPYFMjs3n1per4SsAys8"

# %%
client = StockHistoricalDataClient(api_key, secret_key)

# %%
def compute_macd(data, fast=12, slow=26, signal=9):
    data['ema_fast'] = data['close'].ewm(span=fast, adjust=False).mean()
    data['ema_slow'] = data['close'].ewm(span=slow, adjust=False).mean()
    data['macd'] = data['ema_fast'] - data['ema_slow']
    data['signal'] = data['macd'].ewm(span=signal, adjust=False).mean()
    data['histogram'] = data['macd'] - data['signal']
    return data

# %%
symbols = ["AAPL", "GOOGL", "AMZN", "META", "MSFT", "NVDA"]
start_date = dt.datetime.now() - dt.timedelta(days=365)
end_date = dt.datetime.now()

request_params = StockBarsRequest(
    symbol_or_symbols=symbols,
    timeframe=TimeFrame.Minute,
    start=start_date,
    end=end_date
)

bars = client.get_stock_bars(request_params).df
stock_dic = {}
for symbol in symbols:
    df = bars[bars.index.get_level_values(0) == symbol].copy()
    df.reset_index(inplace=True)
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)
    df=compute_macd(df)
    stock_dic[symbol] = df

print(stock_dic["AAPL"].head())
print(stock_dic["GOOGL"].head())
print(stock_dic["AMZN"].head())
print(stock_dic["META"].head())
print(stock_dic["MSFT"].head())
print(stock_dic["NVDA"].head())
# Out:
#                           symbol    open    high     low   close  volume  \
# timestamp
# 2024-04-01 08:00:00+00:00   AAPL  172.02  172.02  171.42  171.65  3307.0
# 2024-04-01 08:01:00+00:00   AAPL  171.70  171.70  171.70  171.70  1159.0
# 2024-04-01 08:02:00+00:00   AAPL  171.74  171.75  171.71  171.75  1823.0
# 2024-04-01 08:04:00+00:00   AAPL  171.83  171.83  171.83  171.83   580.0
# 2024-04-01 08:10:00+00:00   AAPL  171.66  171.66  171.66  171.66   315.0
#
#                            trade_count        vwap    ema_fast    ema_slow  \
# timestamp
# 2024-04-01 08:00:00+00:00        163.0  171.678633  171.650000  171.650000
# 2024-04-01 08:01:00+00:00         52.0  171.700000  171.657692  171.653704
# 2024-04-01 08:02:00+00:00         33.0  171.737000  171.671893  171.660837
# 2024-04-01 08:04:00+00:00         16.0  171.830000  171.696218  171.673367
# 2024-04-01 08:10:00+00:00         32.0  171.660000  171.690646  171.672377
#
#                                macd    signal  histogram
# timestamp
# 2024-04-01 08:00:00+00:00  0.000000  0.000000   0.000000
# 2024-04-01 08:01:00+00:00  0.003989  0.000798   0.003191
# 2024-04-01 08:02:00+00:00  0.011057  0.002850   0.008207
# 2024-04-01 08:04:00+00:00  0.022850  0.006850   0.016001
# 2024-04-01 08:10:00+00:00  0.018268  0.009133   0.009135
#                           symbol    open    high     low   close  volume  \
# timestamp
# 2024-04-01 08:00:00+00:00  GOOGL  151.20  151.40  151.04  151.26  4249.0
# 2024-04-01 08:01:00+00:00  GOOGL  151.37  151.59  151.37  151.59  2061.0
# 2024-04-01 08:02:00+00:00  GOOGL  151.59  151.64  151.58  151.59  2208.0
# 2024-04-01 08:04:00+00:00  GOOGL  151.60  151.60  151.60  151.60   125.0
# 2024-04-01 08:05:00+00:00  GOOGL  151.59  151.65  151.58  151.65  2593.0
#
#                            trade_count        vwap    ema_fast    ema_slow  \
# 2024-04-01 08:12:00+00:00  0.063613  0.018466   0.045147
# 2024-04-01 08:21:00+00:00  0.130073  0.040788   0.089285
# 2024-04-01 08:25:00+00:00  0.180660  0.068762   0.111898
#                           symbol    open    high     low   close  volume  \
# timestamp
# 2024-04-01 08:00:00+00:00   MSFT  423.00  424.48  423.00  424.43  1988.0
# 2024-04-01 08:01:00+00:00   MSFT  424.58  424.58  424.18  424.25  3930.0
# 2024-04-01 08:03:00+00:00   MSFT  423.36  424.00  423.33  423.33  1746.0
# 2024-04-01 08:04:00+00:00   MSFT  423.41  423.41  423.41  423.41   236.0
# 2024-04-01 08:14:00+00:00   MSFT  423.78  423.78  423.78  423.78   411.0
#
#                            trade_count        vwap    ema_fast    ema_slow  \
# timestamp
# 2024-04-01 08:00:00+00:00        107.0  424.046057  424.430000  424.430000
# 2024-04-01 08:01:00+00:00         58.0  424.304992  424.402308  424.416667
# 2024-04-01 08:03:00+00:00         59.0  423.685000  424.237337  424.336173
# 2024-04-01 08:04:00+00:00         10.0  423.410000  424.110055  424.267567
# 2024-04-01 08:14:00+00:00          8.0  423.780000  424.059277  424.231451
#
#                                macd    signal  histogram
# timestamp
# 2024-04-01 08:00:00+00:00  0.000000  0.000000   0.000000
# 2024-04-01 08:01:00+00:00 -0.014359 -0.002872  -0.011487
# 2024-04-01 08:03:00+00:00 -0.098836 -0.022065  -0.076771
# 2024-04-01 08:04:00+00:00 -0.157513 -0.049154  -0.108359
# 2024-04-01 08:14:00+00:00 -0.172174 -0.073758  -0.098416
#                           symbol    open    high     low   close  volume  \
# timestamp
# 2024-04-01 08:00:00+00:00   NVDA  912.00  912.80  910.00  910.00  5504.0
# 2024-04-01 08:01:00+00:00   NVDA  911.99  913.00  911.99  913.00  6404.0
# 2024-04-01 08:02:00+00:00   NVDA  913.00  913.50  913.00  913.50  3756.0
# 2024-04-01 08:03:00+00:00   NVDA  913.00  913.00  913.00  913.00  1835.0
# 2024-04-01 08:04:00+00:00   NVDA  911.58  911.58  911.58  911.58  1083.0
#
#                            trade_count        vwap    ema_fast    ema_slow  \
# timestamp
# 2024-04-01 08:00:00+00:00        282.0  911.536200  910.000000  910.000000
# 2024-04-01 08:01:00+00:00        256.0  912.700611  910.461538  910.222222
# 2024-04-01 08:02:00+00:00        122.0  913.073797  910.928994  910.465021
# 2024-04-01 08:03:00+00:00         74.0  913.000000  911.247610  910.652797
# 2024-04-01 08:04:00+00:00         65.0  911.580000  911.298747  910.721479
#
#                                macd    signal  histogram
# timestamp
# 2024-04-01 08:00:00+00:00  0.000000  0.000000   0.000000
# 2024-04-01 08:01:00+00:00  0.239316  0.047863   0.191453
# 2024-04-01 08:02:00+00:00  0.463974  0.131085   0.332888
# 2024-04-01 08:03:00+00:00  0.594814  0.223831   0.370983
# 2024-04-01 08:04:00+00:00  0.577269  0.294518   0.282750

# %%
initial_capital = 100_000
position_size_pct = 0.10
stop_loss_pct = 0.02
leverage = 2.0
trailing_stop_pct = 0.015
risk_free_rate = 0.01

capital = initial_capital
positions = []
in_position = False
entry_price = 0
position_direction = 0
trailing_stop = None
entry_time = None

equity_curve = []
returns = []
trade_log = []

for i in range(1, len(df)):
    row = df.iloc[i]
    prev_row = df.iloc[i - 1]

    if in_position:
        price_change = (row['close'] - entry_price) / entry_price * position_direction
        leveraged_return = leverage * price_change * position_size_pct

        if position_direction == 1:
            trailing_stop = max(trailing_stop, row['close'] * (1 - trailing_stop_pct))
            if row['close'] <= trailing_stop or price_change <= -stop_loss_pct:
                exit_time = row.name
                exit_price = row['close']
                trade_log.append({
                    'entry_time': entry_time,
                    'entry_price': entry_price,
                    'exit_time': exit_time,
                    'exit_price': exit_price,
                    'direction': 'long'
                })
                in_position = False
                capital *= 1 + leveraged_return
                returns.append(leveraged_return)
                continue
        elif position_direction == -1:
            trailing_stop = min(trailing_stop, row['close'] * (1 + trailing_stop_pct))
            if row['close'] >= trailing_stop or price_change <= -stop_loss_pct:
                exit_time = row.name
                exit_price = row['close']
                trade_log.append({
                    'entry_time': entry_time,
                    'entry_price': entry_price,
                    'exit_time': exit_time,
                    'exit_price': exit_price,
                    'direction': 'short'
                })
                in_position = False
                capital *= 1 + leveraged_return
                returns.append(leveraged_return)
                continue

    if not in_position:
        if prev_row['macd'] < prev_row['signal'] and row['macd'] > row['signal']:
            in_position = True
            entry_price = row['close']
            position_direction = 1
            trailing_stop = entry_price * (1 - trailing_stop_pct)
            entry_time = row.name
        elif prev_row['macd'] > prev_row['signal'] and row['macd'] < row['signal']:
            in_position = True
            entry_price = row['close']
            position_direction = -1
            trailing_stop = entry_price * (1 + trailing_stop_pct)
            entry_time = row.name

    equity_curve.append(capital)

df['equity'] = pd.Series(equity_curve, index=df.index[:len(equity_curve)]).reindex(df.index, method='ffill')

# %%
returns = np.array(returns)
cumulative_return = df['equity'].iloc[-1] / initial_capital - 1
win_rate = np.mean(returns > 0)
sharpe_ratio = (np.mean(returns) - risk_free_rate / len(returns)) / (np.std(returns) + 1e-9)
rolling_max = df['equity'].cummax()
drawdown = df['equity'] / rolling_max - 1
max_drawdown = drawdown.min()

print(f"Total Return: {cumulative_return:.2%}")
print(f"Win Rate: {win_rate:.2%}")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Max Drawdown: {max_drawdown:.2%}")
# Out:
# Total Return: -26.89%
# Win Rate: 35.43%
# Sharpe Ratio: -0.05
# Max Drawdown: -30.64%

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index[:len(equity_curve)], equity_curve, label='Strategy Equity')
plt.axhline(initial_capital, color='gray', linestyle='--', label='Initial Capital')
plt.title("MACD Strategy with Leverage & Trailing Stop")
plt.legend()
plt.show()

plt.figure(figsize=(12, 4))
plt.plot(drawdown, label='Drawdown')
plt.fill_between(drawdown.index, drawdown, color='red', alpha=0.3)
plt.title("Drawdown Curve")
plt.legend()
plt.show()

# %%
trades_df = pd.DataFrame(trade_log)

plt.figure(figsize=(14, 14))
plt.plot(df['close'], label='MAG6 Stock Price', color='black')

for _, trade in trades_df.iterrows():
    color = 'green' if trade['direction'] == 'long' else 'red'
   # plt.axvline(trade['entry_time'], color=color, linestyle='--', alpha=0.5)
    plt.scatter(trade['entry_time'], trade['entry_price'], color=color, marker='^' if color == 'green' else 'v', zorder=5)
   # plt.axvline(trade['exit_time'], color=color, linestyle=':', alpha=0.5)
    plt.scatter(trade['exit_time'], trade['exit_price'], color=color, marker='x', zorder=5)

plt.title("MACD Strategy Trade Annotations")
plt.legend(['Price'])
plt.tight_layout()
plt.show()

# %%
## put performance of each individual stock
